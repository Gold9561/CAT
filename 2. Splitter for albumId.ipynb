# %% [markdown]
# 1. 구글드라이브에 연결 및 pandas, numpy, 모듈 import

# %%
from google.colab import drive
import pandas as pd
import numpy as np

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. pandas를 통해 excel파일을 불러 온 후, 파일을 분할

# %%
# 한 개의 파일에서 가지고 있을 album_id의 개수 지정
chunksize = 200

num = 0

df = pd.read_excel('/content/drive/MyDrive/team cat/02.입력 데이터처리 출력 과정/Scraper/data/앨범Id_중복값제거.xlsx')

for chunk in np.array_split(df, len(df) // chunksize):
    chunk.to_excel('/content/drive/MyDrive/team cat/02.입력 데이터처리 출력 과정/Scraper/chunk/file_{:02d}.xlsx'.format(i), encoding='utf-8' ,index=False)
    num = num + 1

print("############ 파일 분할이 모두 완료되었습니다. ############")
print("############ 분할된 파일의 총 갯수는 "+str(num) +"개 입니다. ############")
